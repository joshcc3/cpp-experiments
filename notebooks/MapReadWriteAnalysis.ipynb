# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv('mapBenchmarks.csv')
groupedDF = df.groupby(['Name', 'Size']).mean()
reshaped = groupedDF.reset_index(level=[0,1]).pivot(index='Size', columns='Name', values='Time')

# %%
reshaped.plot()

# %%
(reshaped['10pctReads'] - reshaped['10pctWrites']).plot()

# %%
df2 = df[df.Size < 8192]
df3 = df2.groupby(['Name', 'Size']).median()
df3.melt
# Out:
#                         Time
# Name            Size
# 10pctReads      1024  1222.0
#                 2048  2243.5
#                 4096  5463.5
# 10pctWrites     1024  1082.0
#                 2048  2411.5
#                 4096  6368.5
# EvenReadsWrites 1024  1067.0
#                 2048  2314.5
#                 4096  5655.0
# ReadOnly        1024   437.5
#                 2048   936.0
#                 4096  1909.5
# WriteOnly       1024   745.5
#                 2048  1486.0
#                 4096  3347.0
